# %% [markdown]
# # 5 Number Summary And Box Plot
#
# #### minimum,Maximum ,Median ,q1,q2,Iqr

# %%
import numpy as np

# %%
lst_marks=[45,32,56,67,78,87,69,45,23,23,98,34,56,77,66,12,15,27,17]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum ,Q1 ,median,Q3
# Out:
# (np.float64(12.0), np.float64(25.0), np.float64(45.0), np.float64(68.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 43.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_finace=Q3+1.5*(IQR)

# %%
lower_fence ,
# higher_finac
# Out:
# (np.float64(-39.5),)

# %%
import seaborn as sns
sns.boxplot(lst_marks,color="red")
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,67,78,87,69,45,23,23,98,34,56,77,66,12,15,27,17,100,150,175]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
